# %%
import numpy as np
from matplotlib import pyplot as plt
import h5py

# %%
# load data
with h5py.File('simulation_results.h5', 'r') as f:
    params = f['params'][:]
    steady_states = f['steady_states'][:]

# %% [markdown]
# # plot solutions
#
# the ratio of E and L firing (r_E / r_L) as a function of two weight values

# %%
plt.imshow()
